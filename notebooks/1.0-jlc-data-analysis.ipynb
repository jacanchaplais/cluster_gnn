# %% [markdown]
# # Particle data analysis

# %% [markdown]
# [Link to important paper](https://arxiv.org)

# %% [markdown]
# $a^\dagger(p) | 0 \rangle = |p \rangle $

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 6.28, 100)
y = np.sin(x)

# %%
plt.plot(x, y)
